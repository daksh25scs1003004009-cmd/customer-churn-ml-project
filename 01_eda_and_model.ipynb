# %% [markdown]
# # Customer Churn Prediction
#
# A compact end-to-end Data Science & Machine Learning project covering EDA, preprocessing, model comparison, evaluation, and inference.

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
df = pd.read_csv('../data/customer_churn.csv')
df.head()

# %% [markdown]
# ## 1. Data inspection

# %%
print(df.shape)
print('\nMissing values:\n', df.isna().sum())
print('\nChurn distribution:\n', df['churn'].value_counts(normalize=True))

# %% [markdown]
# ## 2. Quick EDA

# %%
df.groupby('contract')['churn'].mean().sort_values(ascending=False).plot(kind='bar')
plt.ylabel('Churn rate')
plt.title('Churn rate by contract type')
plt.tight_layout()
plt.show()

# %%
df.groupby('internet_service')['churn'].mean().sort_values(ascending=False).plot(kind='bar')
plt.ylabel('Churn rate')
plt.title('Churn rate by internet service')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Train and compare models
#
# The production training script in `src/train.py` performs the full preprocessing and model-comparison workflow. Running that script is the recommended reproducible path.

# %%
import json
from pathlib import Path
metrics = json.loads(Path('../reports/metrics.json').read_text()) if Path('../reports/metrics.json').exists() else None
metrics

# %% [markdown]
# ## 4. Interpretation
#
# The model is intended for demonstration and learning. It should not be used for real customer decisions without validating on a real, representative dataset and checking business, fairness, and privacy constraints.
